# %% [markdown]
# ### Boston 주택 가격 예측(Linear Regression, scikit-learn 사용)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# EDA : 탐색적 데이터 분석
df = pd.read_csv('boston_train.csv')

# 시각화
plt.scatter(df['RM'],df['MEDV'],c='r',s=10)
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.title('Boston Housing Data')
plt.grid()
plt.show()
df
# Out:
#          CRIM    ZN  INDUS    NOX     RM   AGE     DIS  TAX  PTRATIO  MEDV
# 0     2.30040   0.0  19.58  0.605  6.319  96.1  2.1000  403     14.7  23.8
# 1    13.35980   0.0  18.10  0.693  5.887  94.7  1.7821  666     20.2  12.7
# 2     0.12744   0.0   6.91  0.448  6.770   2.9  5.7209  233     17.9  26.6
# 3     0.15876   0.0  10.81  0.413  5.961  17.5  5.2873  305     19.2  21.7
# 4     0.03768  80.0   1.52  0.404  7.274  38.3  7.3090  329     12.6  34.6
# ..        ...   ...    ...    ...    ...   ...     ...  ...      ...   ...
# 395   0.23912   0.0   9.69  0.585  6.019  65.3  2.4091  391     19.2  21.2
# 396   0.04560   0.0  13.89  0.550  5.888  56.0  3.1121  276     16.4  23.3
# 397   1.38799   0.0   8.14  0.538  5.950  82.0  3.9900  307     21.0  13.2
# 398   7.36711   0.0  18.10  0.679  6.193  78.1  1.9356  666     20.2  11.0
# 399   0.14150   0.0   6.91  0.448  6.169   6.6  5.7209  233     17.9  25.3
#
# [400 rows x 10 columns]

# %%
df_10=temp.loc[(temp['cd_biztyp4']> 1000)&(temp['cd_biztyp4']<3500),:]
df_10 # 제조업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_10[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']],df_10[['매출금액']])
y_true=df_10[['매출금액']].values
y_pred=lm.predict(df_10[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']])

df_35=finance_set.loc[(finance_set['cd_biztyp4']> 3500)&(finance_set['cd_biztyp4']<3600),:]
df_35 # 전기, 가스, 증기 및 공기 조절 공급업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_35[['자산_토지_cumsum','부채_장기차입금_cumsum']],df_35[['매출금액']])
y_true=df_35[['매출금액']].values
y_pred=lm.predict(df_35[['자산_토지_cumsum','부채_장기차입금_cumsum']])

df_36=finance_set.loc[(finance_set['cd_biztyp4']> 3700)&(finance_set['cd_biztyp4']<4000),:]
df_36 # 수도, 하수 및 폐기물 처리, 원료재생업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_36[['제조_세금과공과금','제조_감가상각비','기타_이자수익','기타_채무면제이익','기타_단기투자자산평가손','자산_보통예금_cumsum','자산_외상매출금_cumsum','자산_미수금_cumsum','부채_부가세예수금_cumsum','부채_미지급세금_cumsum','부채_미지급비용_cumsum','자본_자본금_cumsum','자본_이월이익잉여금_cumsum','매입거래처수','매출_거래건수']],df_36[['매출금액']])
y_true=df_36[['매출금액']].values
y_pred=lm.predict(df_36[['제조_세금과공과금','제조_감가상각비','기타_이자수익','기타_채무면제이익','기타_단기투자자산평가손','자산_보통예금_cumsum','자산_외상매출금_cumsum','자산_미수금_cumsum','부채_부가세예수금_cumsum','부채_미지급세금_cumsum','부채_미지급비용_cumsum','자본_자본금_cumsum','자본_이월이익잉여금_cumsum','매입거래처수','매출_거래건수']])

df_41=finance_set.loc[(finance_set['cd_biztyp4']> 4100)&(finance_set['cd_biztyp4']<4300),:]
df_41 # 건설업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_41[['도급_장비사용료','자산_단기대여금_cumsum','자산_구축물_cumsum','부채_예수금_cumsum','부채_단기차입금_cumsum','부채_퇴직급여충당부채_cumsum','자본_이월이익잉여금_cumsum']],df_41[['매출금액']])
y_true=df_41[['매출금액']].values
y_pred=lm.predict(df_41[['도급_장비사용료','자산_단기대여금_cumsum','자산_구축물_cumsum','부채_예수금_cumsum','부채_단기차입금_cumsum','부채_퇴직급여충당부채_cumsum','자본_이월이익잉여금_cumsum']])

df_45=finance_set.loc[(finance_set['cd_biztyp4']> 4500)&(finance_set['cd_biztyp4']<4800),:]
df_45 # 도매 및 소매업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_45[['자산_제품','자산_외상매출금_cumsum','자산_상품_cumsum','부채_외상매입금_cumsum']],df_45[['매출금액']])
y_true=df_45[['매출금액']].values
y_pred=lm.predict(df_45[['자산_제품','자산_외상매출금_cumsum','자산_상품_cumsum','부채_외상매입금_cumsum']])

df_49=finance_set.loc[(finance_set['cd_biztyp4']> 4900)&(finance_set['cd_biztyp4']<5300),:]
df_49 # 운수 및 창고업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_49[['자산_외상매출금_cumsum','자본_이익준비금_cumsum','자본_이월이익잉여금_cumsum']],df_49[['매출금액']])
y_true=df_49[['매출금액']].values
y_pred=lm.predict(df_49[['자산_외상매출금_cumsum','자본_이익준비금_cumsum','자본_이월이익잉여금_cumsum']])

df_55=finance_set.loc[(finance_set['cd_biztyp4']> 5500)&(finance_set['cd_biztyp4']<5700),:]
df_55 # 숙박 및 음식점업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_55[['자산_제품','판관비_임원급여','판관비_제수당','자산_원재료_cumsum','자산_임차보증금_cumsum','부채_미지급금_cumsum','부채_부가세예수금_cumsum','매입거래처수','분양_상여금','분양_접대비']],df_55[['매출금액']])
y_true=df_55[['매출금액']].values
y_pred=lm.predict(df_55[['자산_제품','판관비_임원급여','판관비_제수당','자산_원재료_cumsum','자산_임차보증금_cumsum','부채_미지급금_cumsum','부채_부가세예수금_cumsum','매입거래처수','분양_상여금','분양_접대비']])

df_58=finance_set.loc[(finance_set['cd_biztyp4']> 5800)&(finance_set['cd_biztyp4']<6400),:]
df_58 # 정보통신업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_58[['제조_제수당','제조_보관료','제조_외주가공비','자산_보통예금_cumsum','자산_외상매출금_cumsum','부채_미지급금','부채_부가세예수금_cumsum']],df_58[['매출금액']])
y_true=df_58[['매출금액']].values
y_pred=lm.predict(df_58[['제조_제수당','제조_보관료','제조_외주가공비','자산_보통예금_cumsum','자산_외상매출금_cumsum','부채_미지급금','부채_부가세예수금_cumsum']])

df_64=finance_set.loc[(finance_set['cd_biztyp4']> 6400)&(finance_set['cd_biztyp4']<6700),:]
df_64 # 금융 및 보험업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_64[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']],df_64[['매출금액']])
y_true=df_64[['매출금액']].values
y_pred=lm.predict(df_64[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']])

df_68=finance_set.loc[(finance_set['cd_biztyp4']> 6800)&(finance_set['cd_biztyp4']<6900),:]
df_68 # 부동산업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_68[['분양_차량유지비','판관비_지급수수료','자산_비품_cumsum','분양_접대비']],df_68[['매출금액']])
y_true=df_68[['매출금액']].values
y_pred=lm.predict(df_68[['분양_차량유지비','판관비_지급수수료','자산_비품_cumsum','분양_접대비']])

df_70=finance_set.loc[(finance_set['cd_biztyp4']> 7000)&(finance_set['cd_biztyp4']<7400),:]
df_70 # 전문, 과학 및 기술 서비스업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_70[['자산_보통예금_cumsum','자산_외상매출금_cumsum','부채_외상매입금_cumsum']],df_70[['매출금액']])
y_true=df_70[['매출금액']].values
y_pred=lm.predict(df_70[['자산_보통예금_cumsum','자산_외상매출금_cumsum','부채_외상매입금_cumsum']])

df_74=finance_set.loc[(finance_set['cd_biztyp4']> 7400)&(finance_set['cd_biztyp4']<7700),:]
df_74 # 사업시설 관리, 사업 지원 및 임대 서비스업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_74[['자본_자기주식처분손잔액','자본_중소기업투자준비금','자본_이월결손금','자본_주식할인발행차금','매입_거래건수','제조_운반비','제조_외주가공비','도급_보험료','분양_보험료','자산_외상매출금_cumsum','자산_상품_cumsum','자산_미착품_cumsum','자산_기계장치_cumsum','자산_건설중인자산_cumsum','자산_미착기계_cumsum','부채_외상매입금_cumsum','부채_지급어음_cumsum','부채_예수금_cumsum','부채_부가세예수금_cumsum','자본_이익준비금_cumsum','자본_기업합리화적립금_cumsum']],df_74[['매출금액']])
y_true=df_74[['매출금액']].values
y_pred=lm.predict(df_74[['자본_자기주식처분손잔액','자본_중소기업투자준비금','자본_이월결손금','자본_주식할인발행차금','매입_거래건수','제조_운반비','제조_외주가공비','도급_보험료','분양_보험료','자산_외상매출금_cumsum','자산_상품_cumsum','자산_미착품_cumsum','자산_기계장치_cumsum','자산_건설중인자산_cumsum','자산_미착기계_cumsum','부채_외상매입금_cumsum','부채_지급어음_cumsum','부채_예수금_cumsum','부채_부가세예수금_cumsum','자본_이익준비금_cumsum','자본_기업합리화적립금_cumsum']])

df_84=finance_set.loc[(finance_set['cd_biztyp4']> 8400)&(finance_set['cd_biztyp4']<8500),:]
df_84 # 공공 행정, 국방 및 사회보장 행정
lm=LinearRegression(n_jobs=-1)
lm.fit(df_84[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']],df_84[['매출금액']])
y_true=df_84[['매출금액']].values
y_pred=lm.predict(df_84[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']])

df_85=finance_set.loc[(finance_set['cd_biztyp4']> 8500)&(finance_set['cd_biztyp4']<8600),:]
df_85 # 공공 행정, 국방 및 사회보장 행정
lm=LinearRegression(n_jobs=-1)
lm.fit(df_85[['기타_이자수익','기타_단기투자자산처분손','자산_임차보증금_cumsum','부채_예수금_cumsum','부채_미지급비용_cumsum']],df_85[['매출금액']])
y_true=df_85[['매출금액']].values
y_pred=lm.predict(df_85[['기타_이자수익','기타_단기투자자산처분손','자산_임차보증금_cumsum','부채_예수금_cumsum','부채_미지급비용_cumsum']])

df_86=finance_set.loc[(finance_set['cd_biztyp4']> 8600)&(finance_set['cd_biztyp4']<8800),:]
df_86 # 보건업 및 사회복지 서비스업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_86[['자산_제품','제조_급여','제조_임금','판관비_잡급','판관비_미분양주택관리비','자산_미수금_cumsum','자산_상품_cumsum','부채_미지급금_cumsum','부채_예수금_cumsum','매입거래처수']],df_86[['매출금액']])
y_true=df_86[['매출금액']].values
y_pred=lm.predict(df_86[['자산_제품','제조_급여','제조_임금','판관비_잡급','판관비_미분양주택관리비','자산_미수금_cumsum','자산_상품_cumsum','부채_미지급금_cumsum','부채_예수금_cumsum','매입거래처수']])

df_90=finance_set.loc[(finance_set['cd_biztyp4']> 9000)&(finance_set['cd_biztyp4']<9200),:]
df_90 # 예술, 스포츠 및 여가관련 서비스업
lm=LinearRegression(n_jobs=-1)
lm.fit(df_90[['자산_현금','자본_전기오류수정이익','자본_전기오류수정손실','도급_소모공구비','도급_잡비','분양_임금','분양_외주비','판관비_수도광열비','자산_현금_cumsum','자산_보통예금_cumsum','자산_기타보증금_cumsum','부채_예수금_cumsum','부채_부가세예수금_cumsum','부채_미지급비용_cumsum','매출거래처수','매출_거래건수']],df_90[['매출금액']])
y_true=df_90[['매출금액']].values
y_pred=lm.predict(df_90[['자산_현금','자본_전기오류수정이익','자본_전기오류수정손실','도급_소모공구비','도급_잡비','분양_임금','분양_외주비','판관비_수도광열비','자산_현금_cumsum','자산_보통예금_cumsum','자산_기타보증금_cumsum','부채_예수금_cumsum','부채_부가세예수금_cumsum','부채_미지급비용_cumsum','매출거래처수','매출_거래건수']])

df_94=finance_set.loc[(finance_set['cd_biztyp4']> 9400)&(finance_set['cd_biztyp4']<9700),:]
df_94 # 협회 및 단체, 수리 및 기타 개인 서비스업
lm94=LinearRegression(n_jobs=-1)
lm94.fit(df_94[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']],df_94[['매출금액']])
y_true=df_94[['매출금액']].values
y_pred=lm.predict(df_94[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']])

df_97=finance_set.loc[(finance_set['cd_biztyp4']> 9700)&(finance_set['cd_biztyp4']<9900),:]
df_97 # 자가 소비 생산활동
lm=LinearRegression(n_jobs=-1)
lm.fit(df_97[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']],df_97[['매출금액']])
y_true=df_97[['매출금액']].values
y_pred=lm.predict(df_97[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']])

df_99=finance_set.loc[(finance_set['cd_biztyp4']> 9900)&(finance_set['cd_biztyp4']<10000),:]
df_99 # 국제 및 외국기관
lm=LinearRegression(n_jobs=-1)
lm.fit(df_99[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']],df_99[['매출금액']])
y_true=df_99[['매출금액']].values
y_pred=lm.predict(df_99[['자산_원재료_cumsum','자산_건물_cumsum','자산_기계장치_cumsum','매입거래처수','매입_거래건수']])

# %%
df1.sort_values(ascending=True)

# %%
# 단항(1차원, 피쳐가 1개) 회귀 모델, scikit-learn 사용
from sklearn.linear_model import LinearRegression

# 클래스 인스턴스를 생성
lr = LinearRegression()

# 입출력 데이터를 설정 : 2차원으로 배열, 데이터프레임으로 입력
x = df['RM'].values.reshape(-1,1)  # (400,) --> (400,1),2차원, -1은 자동 계산
y = df['MEDV'].values.reshape(-1,1)  # (400,) --> (400,1),2차원, -1은 자동 계산

# 학습 : x,y를 입력
lr.fit(x,y)

# 회귀 계수
print(lr.coef_)        # weight : [[9.02315014]] (가중치)
print(lr.intercept_)   # bias   : [-33.99803804]
                       # H(x) = 9.02315014*x + -33.99803804

# 예측 : x값만 입력
y_pred = lr.predict(x)

# 결과 시각화
# 원본의 출력(scatter plot)
plt.scatter(x,y,color = 'r',s =10)
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.title('Boston Housing Data')
plt.grid()

# 예측 함수(직선 그래프) : H(x) = 9.02315014*x + -33.99803804
plt.plot(x,y_pred)
plt.show()

# list(zip(y,y_pred))
# Out:
# [[9.02315014]]
# [-33.99803804]
# [(array([23.8]), array([23.01924771])),
#  (array([12.7]), array([19.12124685])),
#  (array([26.6]), array([27.08868843])),
#  (array([21.7]), array([19.78895996])),
#  (array([34.6]), array([31.6363561])),
#  (array([35.4]), array([28.87527216])),
#  (array([18.6]), array([19.0941774])),
#  (array([33.1]), array([29.00159626])),
#  (array([16.4]), array([26.46609107])),
#  (array([15.2]), array([15.21422284])),
#  (array([5.]), array([15.20519969])),
#  (array([28.4]), array([25.69912331])),
#  (array([25.]), array([23.73207658])),
#  (array([30.7]), array([29.29033706])),
#  (array([15.6]), array([21.51238164])),
#  (array([41.3]), array([28.6496934])),
#  (array([24.2]), array([23.90351643])),
#  (array([23.2]), array([24.08397943])),
#  (array([21.9]), array([45.22522022])),
#  (array([26.6]), array([25.82544741])),
#  (array([23.4]), array([20.12281652])),
#  (array([24.7]), array([19.83407571])),
#  (array([14.9]), array([22.85683101])),
# ...

# %%
# 정확도 측정, RMSE, 상대 지표(값이 작을 수록 정확도가 높다)
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y,y_pred) # 평균 제곱 오차
rmse = np.sqrt(mse)                # 평균 제곱근 오차
print('RMSE:',rmse)                # RMSE: 6.964958263761021

# R2(R-squared), 결정 계수 : 예측 값의 분산/실제 값의 분산, 1일때 가장 설명력 높다
from sklearn.metrics import r2_score
r2 = r2_score(y,y_pred)
print('r2_score:',r2)     # r2_score: 0.46928062004385107
# Out:
# RMSE: 6.964958263761021
# r2_score: 0.46928062004385107

# %%
# 다항(다차원, 피쳐가 2개이상) 회귀 모델, scikit-learn 사용
x = df.iloc[:,:-1]  # 9개 컬럼을 피쳐로 사용, (400, 9), 2차원
y = df['MEDV'].values.reshape(-1,1)    #(400, 1), 2차원, DataFrame
y = df.iloc[:,-1:]                     # (400, 1), 2차원, DataFrame

# 클래스의 인스턴스 생성
lr = LinearRegression()

# 학습
lr.fit(x,y)

# 회귀 계수 확인
print(lr.coef_)        # weight이 9개 생성,
print(lr.intercept_)   # bias는 1개
                       # H(x1, x2, ...,x9) = w1*x1 + w2*x2+...+w9*x9 +b

# 예측
y_pred = lr.predict(x)

# 결과 시각화 : x축을 예측값, y축을 실제값
plt.scatter(y_pred,y,c = 'r',s=10)
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.grid(True)
plt.show()

# 정확도 측정
mse = mean_squared_error(y,y_pred)
rmse = np.sqrt(mse)
print('RMSE:',rmse)   # RMSE: 5.753475905312981, 단항 회귀보다 감소, 정확도 증가

r2 = r2_score(y,y_pred)
print('r2_score:',r2)  # r2_score: 0.6378499850549992, 단항 회귀보다 증가, 정확도 증가
# Out:
# [[-1.59072134e-01  4.08534780e-02 -1.18682966e-01 -2.14042031e+01
#    6.06293561e+00 -4.40157092e-02 -1.81025024e+00  4.29464930e-04
#   -1.08359905e+00]]
# [27.68496713]
# RMSE: 5.753475905312981
# r2_score: 0.6378499850549992

# %%
df.corr()  # 각 피쳐들이 주택가격('MEDV') 어느 정도 영향을 준다.
# Out:
#              CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# CRIM     1.000000 -0.197764  0.383433  0.407698 -0.219043  0.350003 -0.377643
# ZN      -0.197764  1.000000 -0.532929 -0.521745  0.328418 -0.561062  0.665677
# INDUS    0.383433 -0.532929  1.000000  0.758157 -0.393738  0.644559 -0.717796
# NOX      0.407698 -0.521745  0.758157  1.000000 -0.309519  0.735999 -0.776624
# RM      -0.219043  0.328418 -0.393738 -0.309519  1.000000 -0.253271  0.211441
# AGE      0.350003 -0.561062  0.644559  0.735999 -0.253271  1.000000 -0.742486
# DIS     -0.377643  0.665677 -0.717796 -0.776624  0.211441 -0.742486  1.000000
# TAX      0.563791 -0.323539  0.722435  0.664923 -0.302268  0.521723 -0.555040
# PTRATIO  0.284306 -0.393904  0.386248  0.185284 -0.395436  0.260205 -0.227288
# MEDV    -0.375836  0.365931 -0.465083 -0.410425  0.685041 -0.368922  0.236714
#
#               TAX   PTRATIO      MEDV
# CRIM     0.563791  0.284306 -0.375836
# ...

# %%
new_df = df.loc[:,['CRIM','RM','TAX']]
new_df
# Out:
#          CRIM     RM  TAX
# 0     2.30040  6.319  403
# 1    13.35980  5.887  666
# 2     0.12744  6.770  233
# 3     0.15876  5.961  305
# 4     0.03768  7.274  329
# ..        ...    ...  ...
# 395   0.23912  6.019  391
# 396   0.04560  5.888  276
# 397   1.38799  5.950  307
# 398   7.36711  6.193  666
# 399   0.14150  6.169  233
#
# [400 rows x 3 columns]

# %%
## 과제1


# 단항(1차원, 피쳐가 1개) 회귀 모델, scikit-learn 사용
from sklearn.linear_model import LinearRegression
df = pd.read_csv('cars.csv')

# 클래스 인스턴스를 생성
lr = LinearRegression()

# 입출력 데이터를 설정 : 2차원으로 배열, 데이터프레임으로 입력
x= df['speed'].values.reshape(-1,1)
y= df['dist'].values.reshape(-1,1)

# 학습 : x,y를 입력
lr.fit(x,y)

# 회귀 계수
print(lr.coef_)        # weight = [[3.93240876]]
print(lr.intercept_)   # bias = [-17.57909489]
                      # H(x) = 3.93240876 *x + -17.57909489

# 예측 : x값만 입력
y_pred = lr.predict(x)

# 결과 시각화
# 원본의 출력(scatter plot)
plt.scatter(x,y,color ='r',s=10)
plt.xlabel('speed')
plt.ylabel('dist')
plt.title('Cars Data')
plt.grid()

# 예측 함수(직선 그래프) : H(x) = 3.93240876 *x + -17.57909489
plt.plot(x,y_pred)
plt.show()
# Out:
# [[3.93240876]]
# [-17.57909489]

# %%
# 정확도 측정, RMSE, 상대 지표(값이 작을 수록 정확도가 높다)
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y,y_pred) # 평균 제곱 오차
rmse = np.sqrt(mse)                # 평균 제곱근 오차
print('RMSE:',rmse)                # RMSE: 15.068855995791377

# R2(R-squared), 결정 계수 : 예측 값의 분산/실제 값의 분산, 1일때 가장 설명력 높다
from sklearn.metrics import r2_score
r2 = r2_score(y,y_pred)
print('r2_score:',r2)    # r2_score: 0.6510793807582509
# Out:
# RMSE: 15.068855995791377
# r2_score: 0.6510793807582509
